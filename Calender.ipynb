# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

url = "https://www.cuny.edu/academics/registrar/fall-2021-academic-calendar/"
response = requests.get(url)
